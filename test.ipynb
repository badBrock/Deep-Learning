# %%
import pandas as pd

data = {"name" : [" john ","brock","steve"],
        "class" : [1,2,3]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      name  class
# 0   john       1
# 1   brock      2
# 2   steve      3
